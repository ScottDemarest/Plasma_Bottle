# %%
from distributed import LocalCluster, Client
cluster = LocalCluster()
cluster
# Out:
# LocalCluster(9a6f5ca0, 'tcp://127.0.0.1:33391', workers=4, threads=12, memory=18.56 GiB)

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:33391' processes=4 threads=12, memory=18.56 GiB>

# %%
from scipy.integrate import quad
import numpy as np
import uproot
from math import pi
from IPython.display import display

def get_Bx(x, y, z, x0, y0, z0, B0, R):
    def integrand_x(t, x, y, z):
        r_mag = np.sqrt((x-R*np.cos(t))**2 + (y-R*np.sin(t))**2 + z**2)
        r_3 = r_mag**3
        return R*z*np.cos(t)/r_3
    a, b = 0, 2*np.pi
    bx = B0*quad(integrand_x, a, b, args=(x-x0, y-y0, z-z0))[0]
    return bx

def get_By(x, y, z, x0, y0, z0, B0, R):
    def integrand_y(t, x, y, z):
        r_mag = np.sqrt((x-R*np.cos(t))**2 + (y-R*np.sin(t))**2 + z**2)
        r_3 = r_mag**3
        return R*z*np.sin(t)/r_3
    a, b = 0, 2*np.pi
    by = B0*quad(integrand_y, a, b, args=(x-x0, y-y0, z-z0))[0]
    return by

def get_Bz(x, y, z, x0, y0, z0, B0, R):
    def integrand_z(t, x, y, z):
        r_mag = np.sqrt((x-R*np.cos(t))**2 + (y-R*np.sin(t))**2 + z**2)
        r_3 = r_mag**3
        return R*(R - y*np.sin(t) - x*np.cos(t))/r_3
    a, b = 0, 2*np.pi
    bz = B0*quad(integrand_z, a, b, args=(x-x0, y-y0, z-z0))[0]
    return bz

def two_rings_x(x,y,z, x0,y0,z0, x1,y1,z1, B0, R):
    Bx_ring1 = get_Bx(x,y,z, x0,y0,z0, B0,R)
    Bx_ring2 = get_Bx(x,y,z, x1,y1,z1, B0,R)
    return Bx_ring1 + Bx_ring2

def two_rings_y(x,y,z, x0,y0,z0, x1,y1,z1, B0, R):
    By_ring1 = get_By(x,y,z, x0,y0,z0, B0,R)
    By_ring2 = get_By(x,y,z, x1,y1,z1, B0,R)
    return By_ring1 + By_ring2

def two_rings_z(x,y,z, x0,y0,z0, x1,y1,z1, B0, R):
    Bz_ring1 = get_Bz(x,y,z, x0,y0,z0, B0,R)
    Bz_ring2 = get_Bz(x,y,z, x1,y1,z1, B0,R)
    return Bz_ring1 + Bz_ring2


# Set parameters
l0 = 2*pi
B0 = 1
R = 0.5*l0

Lx           = 2.*l0
Ly           = 2.*l0
Lz           = 2.*l0

#Ring 1
x0 = Lx/2
y0 = Ly/2
z0 = .1*Lz

#Ring 2
x1 = Lx/2
y1 = Ly/2
z1 = .9*Lz

# Resolution
resx         = 8.      #64               # nb of cells in one laser wavelength
resy         = 8.                     
resz         = 8.

# Domain
dx           = l0/resx
dy           = l0/resy
dz           = l0/resz

Nx = Lx/dx
Ny = Ly/dy
Nz = Lz/dz

print(f"Lx: {int(Lx)}")
print(f"Nx: {int(Nx)}")

x = np.linspace(0, Lx, int(Nx))
y = np.linspace(0, Ly, int(Ny))
z = np.linspace(0, Lz, int(Nz))

print("Calculating B components.")
Ax = []
Ay = []
Az = []
num = 0
x_index = 0

dh = display(" ",display_id=True)

for k in z:
    num = num + 1
    dh.update(f"{num} out of {len(x)}")
    for j in y:
        for i in x:
            Ax.append(client.submit(two_rings_x, i,j,k, x0,y0,z0, x1,y1,z1, B0, R))
            Ay.append(client.submit(two_rings_y, i,j,k, x0,y0,z0, x1,y1,z1, B0, R))
            Az.append(client.submit(two_rings_z, i,j,k, x0,y0,z0, x1,y1,z1, B0, R))
# Out:
# Lx: 12
# Nx: 16
# Calculating B components.
# '16 out of 16'

# %%
Bx_flat = client.gather(Ax)
By_flat = client.gather(Ay)
Bz_flat = client.gather(Az)

# %%
import dask.array as da
Nx = int(Nx)
Ny = int(Ny)
Nz = int(Nz)
Bx_flat_dask = da.asarray(Bx_flat).compute()
Bx = Bx_flat_dask.reshape((Nz, Ny, Nx)).transpose()
By_flat_dask = da.asarray(By_flat).compute()
By = By_flat_dask.reshape((Nz, Ny, Nx)).transpose()
Bz_flat_dask = da.asarray(Bz_flat).compute()
Bz = Bz_flat_dask.reshape((Nz, Ny, Nx)).transpose()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1738/283764021.py in <module>
#       2
#       3 Bx_flat_dask = da.asarray(Bx_flat).compute()
# ----> 4 Bx = Bx_flat_dask.reshape((Nz, Ny, Nx)).transpose()
#       5 By_flat_dask = da.asarray(By_flat).compute()
#       6 By = By_flat_dask.reshape((Nz, Ny, Nx)).transpose()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
with uproot.recreate("B_field_inputs.root") as f:
    f["B_field"] = {"Bx": Bx, "By": By, "Bz": Bz}
    #f["B_field"] = {"Bx": Bx, "Bz": Bz}
